# %% [markdown]
# **LOADING DATA IN PANDA**

# %%
##library 
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import time
from bs4 import BeautifulSoup
import requests
# %matplotlib inline
##loading the data

df=pd.read_csv('Netflix Shows.csv', encoding='latin-1')
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 0            2004               82.0                80
# 1            2006                NaN                82
# 2            2016               98.0                80
# 3            2008               98.0                80
# 4            2014               94.0                80
# ..            ...                ...               ...
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# 999          2016               80.0                80
#
# [1000 rows x 7 columns]

# %% [markdown]
# **READ THE DATA**

# %%
df.head(100)
# Out:
#                                       title rating  \
# 900                           Cool Runnings     PG
# 901  Homeward Bound: The Incredible Journey      G
# 902                               Anastasia      G
# 903                                    Antz     PG
# 904                   Babe: Pig in the City      G
# ..                                      ...    ...
# 995                                 The BFG     PG
# 996                 The Secret Life of Pets     PG
# 997                        Precious Puppies   TV-G
# 998                             Beary Tales   TV-G
# 999                         Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 900  Parental guidance suggested. May not be suitab...                 60
# 901          General Audiences. Suitable for all ages.                 35
# 902          General Audiences. Suitable for all ages.                 35
# 903         moderate adult language and intense action                 60
# 904          General Audiences. Suitable for all ages.                 35
# ..                                                 ...                ...
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 900          1993               81.0                80
# 901          1993               96.0                80
# 902          1997               93.0                80
# 903          1998               80.0                80
# 904          1998                NaN                82
# ..            ...                ...               ...
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# 999          2016               80.0                80
#
# [100 rows x 7 columns]

# %% [markdown]
# **Drop duplicate rows**

# %%
nf=df.drop_duplicates()
nf
# Out:
#                          title rating  \
# 0                 White Chicks  PG-13
# 1          Lucky Number Slevin      R
# 2               Grey's Anatomy  TV-14
# 3                 Prison Break  TV-14
# 4        How I Met Your Mother  TV-PG
# ..                         ...    ...
# 989            Russell Madness     PG
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# 989                  some rude humor and sports action                 60
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
#
#      release year  user rating score  user rating size
# 0            2004               82.0                80
# 1            2006                NaN                82
# 2            2016               98.0                80
# 3            2008               98.0                80
# 4            2014               94.0                80
# ..            ...                ...               ...
# 989          2015                NaN                82
# 993          2015                NaN                82
# 994          2016                NaN                82
# 997          2003                NaN                82
# 998          2013                NaN                82
#
# [500 rows x 7 columns]

# %% [markdown]
# **DESCRIBING THE DATA**

# %%
nf.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         500.000000    500.000000         256.000000        500.000000
# mean           68.754000   2010.976000          81.398438         80.972000
# std            31.505089      7.829305          12.730904          0.998604
# min            10.000000   1940.000000          55.000000         80.000000
# 25%            41.000000   2009.000000          71.000000         80.000000
# 50%            70.000000   2014.000000          83.500000         80.000000
# 75%            90.000000   2016.000000          93.000000         82.000000
# max           124.000000   2017.000000          99.000000         82.000000

# %% [markdown]
# **SORTING**

# %%
nf.sort_values('release year',ascending=False)
# Out:
#                               title rating  \
# 102                         Chelsea  TV-MA
# 112                      Win It All  TV-MA
# 41                   13 Reasons Why  TV-MA
# 42                      Sand Castle  TV-MA
# 44                     Sandy Wexler  TV-14
# ..                              ...    ...
# 379                           Annie     PG
# 423                The Last Unicorn      G
# 170                          Grease     PG
# 270  The Smurfs and the Magic Flute      G
# 412                        Fantasia      G
#
#                                            ratingLevel  ratingDescription  \
# 102  For mature audiences.  May not be suitable for...                110
# 112                                                NaN                110
# 41   For mature audiences.  May not be suitable for...                110
# 42                                                 NaN                110
# 44                                                 NaN                 90
# ..                                                 ...                ...
# 379                     adult content and mld violence                 60
# 423          General Audiences. Suitable for all ages.                 35
# 170  Parental guidance suggested. May not be suitab...                 60
# 270          General Audiences. Suitable for all ages.                 35
# 412          General Audiences. Suitable for all ages.                 35
#
#      release year  user rating score  user rating size
# 102          2017                NaN                82
# 112          2017                NaN                82
# 41           2017               99.0                80
# 42           2017               89.0                80
# 44           2017               92.0                80
# ..            ...                ...               ...
# 379          1982               68.0                80
# 423          1982                NaN                82
# 170          1978               86.0                80
# 270          1976                NaN                82
# 412          1940               61.0                80
#
# [500 rows x 7 columns]

# %% [markdown]
# **AGGREGATE STATISTICS (GROUPBY)**

# %%
df.groupby(['title']).mean().sort_values('user rating size',ascending=False)
# Out:
#                                             ratingDescription  release year  \
# title
# Marvel Super Hero Adventures: Frost Fight!               60.0        2015.0
# Salvador Martinha - Tip of the Tongue                   110.0        2016.0
# Pandora                                                 110.0        2016.0
# Pac-Man and the Ghostly Adventures                       41.0        2014.0
# Oscar's Oasis                                            35.0        2011.0
# ...                                                       ...           ...
# Only for One Night                                      110.0        2016.0
# One Tree Hill                                            90.0        2011.0
# Death in Paradise                                        90.0        2016.0
# Once Upon a Time                                         70.0        2016.0
# 10 Things I Hate About You                               80.0        1999.0
#
#                                             user rating score  \
# title
# Marvel Super Hero Adventures: Frost Fight!                NaN
# Salvador Martinha - Tip of the Tongue                     NaN
# Pandora                                                   NaN
# Pac-Man and the Ghostly Adventures                        NaN
# Oscar's Oasis                                             NaN
# ...                                                       ...
# Only for One Night                                       78.0
# One Tree Hill                                            90.0
# Death in Paradise                                        77.0
# Once Upon a Time                                         98.0
# 10 Things I Hate About You                               68.0
#
#                                             user rating size
# title
# Marvel Super Hero Adventures: Frost Fight!              82.0
# Salvador Martinha - Tip of the Tongue                   82.0
# Pandora                                                 82.0
# Pac-Man and the Ghostly Adventures                      82.0
# Oscar's Oasis                                           82.0
# ...                                                      ...
# Only for One Night                                      80.0
# One Tree Hill                                           80.0
# Death in Paradise                                       80.0
# Once Upon a Time                                        80.0
# 10 Things I Hate About You                              80.0
#
# [496 rows x 4 columns]

# %% [markdown]
# **FILTERING THE DATA**

# %%
new_nf=nf.loc[df['user rating size']>80]
new_nf
# Out:
#                          title rating  \
# 1          Lucky Number Slevin      R
# 14                  The Hunter      R
# 15       Lottie Dottie Chicken   TV-Y
# 21   ÌÒ Pai, ÌÒ - Look at This  TV-MA
# 22      Nymphomaniac: Volume 1     NR
# ..                         ...    ...
# 479                  Mr. Magoo     PG
# 484         Inspector Gadget 2      G
# 485       Air Bud: Spikes Back      G
# 488                Air Buddies     PG
# 495            Russell Madness     PG
#
#                                            ratingLevel  ratingDescription  \
# 1    strong violence, sexual content and adult lang...                100
# 14                         language and brief violence                100
# 15                              Suitable for all ages.                 10
# 21   For mature audiences.  May not be suitable for...                110
# 22                      This movie has not been rated.                124
# ..                                                 ...                ...
# 479                 mild language and action sequences                 60
# 484          General Audiences. Suitable for all ages.                 35
# 485          General Audiences. Suitable for all ages.                 35
# 488                              some mild, rude humor                 60
# 495                  some rude humor and sports action                 60
#
#      release year  user rating score  user rating size
# 1            2006                NaN                82
# 14           2011                NaN                82
# 15           2009                NaN                82
# 21           2007                NaN                82
# 22           2013                NaN                82
# ..            ...                ...               ...
# 479          1997                NaN                82
# 484          2003                NaN                82
# 485          2003                NaN                82
# 488          2006                NaN                82
# 495          2015                NaN                82
#
# [133 rows x 7 columns]

# %% [markdown]
# **BAR GRAPH**

# %%
score_freq = nf['user rating size'].value_counts()

plt.figure(figsize=(15,10))
score_freq.plot.bar(color='red', alpha=0.5)
plt.xticks(rotation=50)
plt.xlabel("User Rating size")
plt.ylabel("Frequency of user rating size")
plt.title("User Rating Size Frequency")
plt.show()
